# %% [markdown]
# # Adding new xeno-canto and inaturalist data to animalspeak2

# %%
import pandas as pd
from gcsfs import GCSFileSystem
import numpy as np
import soundfile as sf

# %% [markdown]
# # Get animalspeak first
