# %%
import pandas as pd

# %%
df = pd.read_csv("/home/gagan/Downloads/splits_v1_animalspeak_eval_v1.3_cluster.csv")

# %%
df.head(3)
# Out:
#                              Associated Taxa  Unnamed: 0  audio_file_name  \
# 0                                        NaN    967164.0              NaN
# 1                                        NaN    673659.0              NaN
# 2  has background sounds: Cinnyris jugularis    529295.0              NaN
#
#    audio_id  audiocap_id background_family background_genus  \
# 0       NaN          NaN               NaN              NaN
# 1       NaN          NaN               NaN              NaN
# 2       NaN          NaN     Nectariniidae         Cinnyris
#
#   background_species_common background_species_sci  \
# 0                       NaN                    NaN
# 1                       NaN                    NaN
# 2      Olive-backed Sunbird     Cinnyris jugularis
#
#                                 background_taxonomic  ... start_time  \
# 0                                                NaN  ...        NaN
# 1                                                NaN  ...        NaN
# ...

# %%
df.columns
# Out:
# Index(['Associated Taxa', 'Unnamed: 0', 'audio_file_name', 'audio_id',
#        'audiocap_id', 'background_family', 'background_genus',
#        'background_species_common', 'background_species_sci',
#        'background_taxonomic', 'behavior', 'canonical_name', 'caption',
#        'caption2', 'caption3', 'class', 'eventDate', 'eventTime', 'family',
#        'fieldNotes', 'gbifID', 'genus', 'identifier', 'latitudeDecimal',
#        'license', 'license_url', 'lifeStage', 'local_path', 'longitudeDecimal',
#        'order', 'path', 'phylum', 'recordist', 'rightsHolder', 'sex', 'source',
#        'species', 'species_common', 'species_scientific',
#        'species_scientific_normalized', 'start_time', 'subspecies',
#        'taxonomic_name', 'url', 'youtube_id', 'country', 'locality',
#        'verbatimElevation', 'extracted_name', 'cluster_path'],
#       dtype='object')

# %%
df.taxonomic_name.sample(n=10).to_dict()
# Out:
# {1449: 'Chordata Aves Apodiformes Apodidae Apus apus',
#  1558: 'Chordata Amphibia Anura Hylidae Pseudacris crucifer',
#  1852: 'Chordata Aves Strigiformes Strigidae Glaucidium gnoma',
#  1761: 'Chordata Aves Passeriformes Fringillidae Linaria cannabina',
#  705: 'Chordata Aves Psittaciformes Psittacidae Forpus xanthopterygius',
#  360: 'Chordata Amphibia Anura Ranidae Lithobates sylvaticus',
#  1881: 'Chordata Aves Passeriformes Regulidae Regulus satrapa',
#  1037: 'Chordata Aves Passeriformes Sylviidae Sylvia atricapilla',
#  1518: 'Chordata Aves Passeriformes Corvidae Corvus corone',
#  383: 'Chordata Aves Passeriformes Troglodytidae Troglodytes hiemalis'}
